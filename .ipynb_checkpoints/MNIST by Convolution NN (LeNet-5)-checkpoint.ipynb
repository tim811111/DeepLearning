# %% [markdown]
# # MNIST by Convolution NN (LeNet-5)
# * 2 conv([5,5],64) 2 maxpooling(strides=2) FC(1024)
# * input=[batch,length,width,deep]
# * Convolution kernel(w) = [length,width,deep_in,deep_out]
# * strides = [1,step,step,1]
# * new_height = new_width = (input — kernel + 1) / Strides

# %%
#import data and library
import numpy as np
import pandas as pd 
import tensorflow as tf
import random
from tensorflow.examples.tutorials.mnist import input_data
old_v = tf.logging.get_verbosity()
tf.logging.set_verbosity(tf.logging.ERROR)

mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)

train_data = mnist.train.images  # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
test_data = mnist.test.images  # Returns np.array
test_labels = np.asarray(mnist.test.labels, dtype=np.int32)

tf.logging.set_verbosity(old_v)
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#def feature map and pooling


def weight_variable(name,shape):
    initializer = tf.contrib.layers.xavier_initializer(seed=1)
    return tf.get_variable(name,shape,initializer=initializer,dtype=tf.float32)

def bias_variable(name,shape):
    return tf.get_variable(name, shape)

def conv2d(inputs, w):
    return tf.nn.conv2d(inputs,w,strides = [1,1,1,1],padding = 'SAME')

def max_pooling_2x2(inputs,x=2,y=2):
    ksize = [1,x,y,1]
    return tf.nn.max_pool(inputs,ksize,strides = [1,2,2,1],padding = 'SAME')

# %%
#set outlines 
inputs_num = 784 # 28*28 =784  (784,1)
outputs_num = 10 # 0 to 9   

#reset variable in tensorflow
tf.reset_default_graph()

#stack data
X = np.vstack([mnist.train.images, mnist.test.images, mnist.validation.images])
y = np.vstack([mnist.train.labels, mnist.test.labels, mnist.validation.labels])

#set placeholder(input and target)
inputs= tf.placeholder(tf.float32,[None,inputs_num],)
targets= tf.placeholder(tf.float32,[None,outputs_num],)
#transfer image to 4D data([batch,in_height,in_width,in_channels])
inputs_image = tf.reshape(inputs,[-1,28,28,1])

#set 1st convolution layer w and b
w_conv1 = weight_variable('w_1',[5,5,1,32])
b_conv1 = bias_variable('b_1',[32])
#set 2nd convolution layer w and b
w_conv2 = weight_variable('w_2',[5,5,32,64])
b_conv2 = bias_variable('b_2',[64])

#convolution layer and max pooling (relu activation function) 2 times pooling 28 ->14 ->7
h_conv1 = tf.nn.relu(conv2d(inputs_image,w_conv1)+b_conv1)
h_pool1 = max_pooling_2x2(h_conv1)

h_conv2 = tf.nn.relu(conv2d(h_pool1,w_conv2)+b_conv2)
h_pool2 = max_pooling_2x2(h_conv2)

#set 1st fully connected variable(last layer 7*7*64, 1024 nuron)
fc_w1 = weight_variable('fc_w1',[7*7*64,1024])
fc_b1 = bias_variable('fc_b1',[1024])

#flatten
h_pool2_flatten = tf.reshape(h_pool2,[-1,7*7*64])

# fully connected 1
fc_1 = tf.nn.relu(tf.matmul(h_pool2_flatten,fc_w1)+fc_b1)

# dropout(testing need turn off)
keep_prop = tf.placeholder(tf.float32)
fc_1_drop = tf.nn.dropout(fc_1,keep_prop)

#set 2nd fully connected variable(last layer 1024, 10 nuron)
fc_w2 = weight_variable('fc_w2',[1024,10])
fc_b2 = bias_variable('fc_b2',[10])

#predicted outputs
outputs = tf.nn.softmax(tf.matmul(fc_1_drop,fc_w2)+fc_b2)

# set loss and optimize object
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=outputs, labels=targets))
# loss = tf.reduce_mean(-tf.reduce_sum(targets * tf.log(outputs), 1))
optimizer = tf.train.AdamOptimizer(learning_rate=0.0001,).minimize(loss)

#after softmax, let probability to 0 or 1 by argmax function, and judge between target and output
out_eql_target = tf.equal(tf.argmax(outputs,1), tf.argmax(targets,1))

#predicte accuracy (need cast to float32)
accuracy = tf.reduce_mean(tf.cast(out_eql_target,tf.float32))

#框架完成

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.4
# session = tf.Session(config=config)
#sess
sess= tf.InteractiveSession()

#initial variable
initializer = tf.global_variables_initializer()
sess.run(initializer)


#set training paramerter
epochs = 10000
batch_num = 256
batch_cycle_a = mnist.train._num_examples // batch_num
batch_cycle_b = mnist.validation._num_examples // batch_num
batch_cycle_c = mnist.test._num_examples // batch_num
prev_validation = 9999999.

#Training model
import time
start = time.time()
for epoch_counter in range(epochs):
    curr_epoc_loss = 0.
    curr_epoc_val = 0.
    curr_epoc_tes = 0.
    for batch_counter in range(batch_cycle_a):
        input_batch, target_batch = mnist.train.next_batch(batch_num)
        _,batch_loss,train_accuracy = sess.run([optimizer,loss,accuracy],
                                feed_dict={inputs:input_batch,targets: target_batch,keep_prop:0.5})
        curr_epoc_loss += batch_loss
    curr_epoc_loss/=batch_cycle_a
    # validation
    for batch_counter in range(batch_cycle_b):
        input_batch, target_batch = mnist.validation.next_batch(batch_num)
        val_loss, val_accuracy = sess.run([loss,accuracy],feed_dict={inputs:input_batch,targets:target_batch, keep_prop:0.5})
        curr_epoc_val += val_loss
    curr_epoc_val/=batch_cycle_b
#     if val_loss>prev_validation:
#         break
#     prev_validation = val_loss


    print(f'Epoch cycle: {epoch_counter + 1}'+
             f' Training loss: {curr_epoc_loss:.3f}'+
             f' Validation loss: {val_loss:.3f}'+
             f' Validation accuracy: {val_accuracy*100.:.2f}'+'%'+
             f' times: {time.time() - start}')
    
    
    for batch_counter in range(batch_cycle_c):
        input_batch, target_batch = mnist.test.next_batch(batch_num)
        test_accuracy = sess.run([accuracy],feed_dict ={inputs:input_batch,targets:target_batch,keep_prop:1})
    test_accuracy_percent=test_accuracy[0]*100.
    print(f'test accuracy: {test_accuracy_percent:.2f}')
    if  train_accuracy and test_accuracy == 1 and val_accuracy == 1 :
        saver = tf.train.Saver()
        save_path = saver.save(sess, 'mnist_cnn_model/mnist_cnn.ckpt')
        print('Save to path:', save_path)
        break
print('end of training')
# Out:
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Epoch cycle: 1 Training loss: 1.883 Validation loss: 1.652 Validation accuracy: 83.98% times: 6.523311376571655
# test accuracy: 90.23
# Epoch cycle: 2 Training loss: 1.576 Validation loss: 1.547 Validation accuracy: 93.36% times: 13.368363618850708
# test accuracy: 92.19
# Epoch cycle: 3 Training loss: 1.535 Validation loss: 1.519 Validation accuracy: 95.31% times: 20.186930894851685
# test accuracy: 95.70
# Epoch cycle: 4 Training loss: 1.517 Validation loss: 1.506 Validation accuracy: 96.09% times: 26.98965096473694
# test accuracy: 97.66
# Epoch cycle: 5 Training loss: 1.506 Validation loss: 1.500 Validation accuracy: 96.09% times: 33.82064747810364
# test accuracy: 98.05
# Epoch cycle: 6 Training loss: 1.500 Validation loss: 1.497 Validation accuracy: 96.88% times: 40.63824200630188
# test accuracy: 98.05
# Epoch cycle: 7 Training loss: 1.496 Validation loss: 1.497 Validation accuracy: 96.09% times: 47.45471739768982
# test accuracy: 98.05
# Epoch cycle: 8 Training loss: 1.491 Validation loss: 1.498 Validation accuracy: 96.48% times: 54.27285552024841
# test accuracy: 96.88
# Epoch cycle: 9 Training loss: 1.489 Validation loss: 1.482 Validation accuracy: 98.44% times: 61.089741945266724
# test accuracy: 98.83
# Epoch cycle: 10 Training loss: 1.487 Validation loss: 1.494 Validation accuracy: 96.88% times: 67.90569519996643
# test accuracy: 97.66
# Epoch cycle: 11 Training loss: 1.484 Validation loss: 1.486 Validation accuracy: 97.27% times: 74.72336912155151
# test accuracy: 98.83
# Epoch cycle: 12 Training loss: 1.483 Validation loss: 1.483 Validation accuracy: 98.05% times: 81.54605650901794
# test accuracy: 98.83
# Epoch cycle: 13 Training loss: 1.482 Validation loss: 1.478 Validation accuracy: 98.83% times: 88.34081697463989
# test accuracy: 100.00
# Epoch cycle: 14 Training loss: 1.480 Validation loss: 1.480 Validation accuracy: 98.44% times: 95.15866017341614
# test accuracy: 97.66
# Epoch cycle: 15 Training loss: 1.479 Validation loss: 1.469 Validation accuracy: 99.61% times: 101.99343609809875
# test accuracy: 98.05
# Epoch cycle: 16 Training loss: 1.478 Validation loss: 1.473 Validation accuracy: 98.83% times: 108.81288623809814
# test accuracy: 99.22
# Epoch cycle: 17 Training loss: 1.478 Validation loss: 1.497 Validation accuracy: 96.88% times: 115.64207220077515
# test accuracy: 98.05
# Epoch cycle: 18 Training loss: 1.477 Validation loss: 1.471 Validation accuracy: 99.22% times: 122.4580545425415
# test accuracy: 97.66
# Epoch cycle: 19 Training loss: 1.476 Validation loss: 1.479 Validation accuracy: 98.44% times: 129.25969219207764
# test accuracy: 99.22
# Epoch cycle: 20 Training loss: 1.475 Validation loss: 1.466 Validation accuracy: 100.00% times: 136.07637405395508
# test accuracy: 98.83
# Epoch cycle: 21 Training loss: 1.475 Validation loss: 1.478 Validation accuracy: 98.05% times: 142.89441633224487
# test accuracy: 98.44
# Epoch cycle: 22 Training loss: 1.474 Validation loss: 1.486 Validation accuracy: 98.05% times: 149.71048188209534
# test accuracy: 97.66
# Epoch cycle: 23 Training loss: 1.473 Validation loss: 1.469 Validation accuracy: 99.22% times: 156.52783250808716
# test accuracy: 98.44
# Epoch cycle: 24 Training loss: 1.473 Validation loss: 1.474 Validation accuracy: 99.22% times: 163.35976552963257
# test accuracy: 98.83
# Epoch cycle: 25 Training loss: 1.472 Validation loss: 1.472 Validation accuracy: 99.22% times: 170.17738699913025
# test accuracy: 98.44
# Epoch cycle: 26 Training loss: 1.472 Validation loss: 1.481 Validation accuracy: 98.05% times: 176.9951195716858
# test accuracy: 99.61
# Epoch cycle: 27 Training loss: 1.471 Validation loss: 1.477 Validation accuracy: 98.83% times: 183.81205701828003
# test accuracy: 97.66
# Epoch cycle: 28 Training loss: 1.471 Validation loss: 1.474 Validation accuracy: 98.83% times: 190.64544463157654
# test accuracy: 99.22
# Epoch cycle: 29 Training loss: 1.471 Validation loss: 1.481 Validation accuracy: 98.44% times: 197.46741366386414
# test accuracy: 98.83
# Epoch cycle: 30 Training loss: 1.471 Validation loss: 1.474 Validation accuracy: 98.83% times: 204.2946331501007
# test accuracy: 98.05
# Epoch cycle: 31 Training loss: 1.470 Validation loss: 1.470 Validation accuracy: 98.83% times: 211.12858200073242
# test accuracy: 100.00
# Epoch cycle: 32 Training loss: 1.470 Validation loss: 1.474 Validation accuracy: 98.83% times: 217.96455931663513
# test accuracy: 99.22
# Epoch cycle: 33 Training loss: 1.469 Validation loss: 1.473 Validation accuracy: 98.83% times: 224.80870079994202
# test accuracy: 98.83
# Epoch cycle: 34 Training loss: 1.470 Validation loss: 1.468 Validation accuracy: 100.00% times: 231.63033866882324
# test accuracy: 99.22
# Epoch cycle: 35 Training loss: 1.469 Validation loss: 1.481 Validation accuracy: 98.44% times: 238.46315693855286
# test accuracy: 99.22
# Epoch cycle: 36 Training loss: 1.469 Validation loss: 1.484 Validation accuracy: 97.66% times: 245.29813170433044
# test accuracy: 98.83
# Epoch cycle: 37 Training loss: 1.468 Validation loss: 1.473 Validation accuracy: 98.83% times: 252.13024282455444
# test accuracy: 99.22
# Epoch cycle: 38 Training loss: 1.468 Validation loss: 1.483 Validation accuracy: 98.05% times: 258.953405380249
# test accuracy: 99.22
# Epoch cycle: 39 Training loss: 1.468 Validation loss: 1.471 Validation accuracy: 99.22% times: 265.7817270755768
# test accuracy: 98.44
# Epoch cycle: 40 Training loss: 1.468 Validation loss: 1.467 Validation accuracy: 99.61% times: 272.61527609825134
# test accuracy: 99.22
# Epoch cycle: 41 Training loss: 1.467 Validation loss: 1.462 Validation accuracy: 100.00% times: 279.4329307079315
# test accuracy: 99.61
# Epoch cycle: 42 Training loss: 1.467 Validation loss: 1.472 Validation accuracy: 98.83% times: 286.28154945373535
# test accuracy: 99.22
# Epoch cycle: 43 Training loss: 1.468 Validation loss: 1.473 Validation accuracy: 98.83% times: 293.1153588294983
# test accuracy: 98.83
# Epoch cycle: 44 Training loss: 1.467 Validation loss: 1.480 Validation accuracy: 98.05% times: 299.93346309661865
# test accuracy: 99.61
# Epoch cycle: 45 Training loss: 1.467 Validation loss: 1.479 Validation accuracy: 98.44% times: 306.76651072502136
# test accuracy: 99.22
# Epoch cycle: 46 Training loss: 1.467 Validation loss: 1.472 Validation accuracy: 98.83% times: 313.59885811805725
# test accuracy: 99.22
# Epoch cycle: 47 Training loss: 1.467 Validation loss: 1.471 Validation accuracy: 99.22% times: 320.4367251396179
# test accuracy: 98.44
# Epoch cycle: 48 Training loss: 1.466 Validation loss: 1.469 Validation accuracy: 99.22% times: 327.25180101394653
# test accuracy: 98.44
# Epoch cycle: 49 Training loss: 1.466 Validation loss: 1.476 Validation accuracy: 98.83% times: 334.08546566963196
# test accuracy: 97.66
# Epoch cycle: 50 Training loss: 1.466 Validation loss: 1.481 Validation accuracy: 98.05% times: 340.93772983551025
# test accuracy: 100.00
# Epoch cycle: 51 Training loss: 1.466 Validation loss: 1.470 Validation accuracy: 99.22% times: 347.7685434818268
# test accuracy: 99.22
# Epoch cycle: 52 Training loss: 1.466 Validation loss: 1.464 Validation accuracy: 99.61% times: 354.60138487815857
# test accuracy: 99.22
# Epoch cycle: 53 Training loss: 1.465 Validation loss: 1.468 Validation accuracy: 99.61% times: 361.4347403049469
# test accuracy: 99.22
# Epoch cycle: 54 Training loss: 1.466 Validation loss: 1.479 Validation accuracy: 98.44% times: 368.26877212524414
# test accuracy: 99.61
# Epoch cycle: 55 Training loss: 1.465 Validation loss: 1.466 Validation accuracy: 99.61% times: 375.1029124259949
# test accuracy: 99.61
# Epoch cycle: 56 Training loss: 1.466 Validation loss: 1.465 Validation accuracy: 100.00% times: 381.9369466304779
# test accuracy: 99.61
# Epoch cycle: 57 Training loss: 1.465 Validation loss: 1.466 Validation accuracy: 99.61% times: 388.7712392807007
# test accuracy: 100.00
# Epoch cycle: 58 Training loss: 1.465 Validation loss: 1.468 Validation accuracy: 99.22% times: 395.6038601398468
# test accuracy: 99.61
# Epoch cycle: 59 Training loss: 1.465 Validation loss: 1.468 Validation accuracy: 99.22% times: 402.45344400405884
# test accuracy: 97.66
# Epoch cycle: 60 Training loss: 1.465 Validation loss: 1.471 Validation accuracy: 98.83% times: 409.28712129592896
# test accuracy: 99.61
# Epoch cycle: 61 Training loss: 1.465 Validation loss: 1.472 Validation accuracy: 98.83% times: 416.1210904121399
# test accuracy: 99.61
# Epoch cycle: 62 Training loss: 1.465 Validation loss: 1.471 Validation accuracy: 99.22% times: 422.95411252975464
# test accuracy: 99.61
# Epoch cycle: 63 Training loss: 1.464 Validation loss: 1.466 Validation accuracy: 99.61% times: 429.77152609825134
# test accuracy: 99.22
# Epoch cycle: 64 Training loss: 1.465 Validation loss: 1.470 Validation accuracy: 98.83% times: 436.62178087234497
# test accuracy: 99.22
# Epoch cycle: 65 Training loss: 1.465 Validation loss: 1.470 Validation accuracy: 99.22% times: 443.4569981098175
# test accuracy: 98.83
# Epoch cycle: 66 Training loss: 1.464 Validation loss: 1.472 Validation accuracy: 99.22% times: 450.28896164894104
# test accuracy: 98.44
# Epoch cycle: 67 Training loss: 1.465 Validation loss: 1.468 Validation accuracy: 99.61% times: 457.1291320323944
# test accuracy: 99.22
# Epoch cycle: 68 Training loss: 1.464 Validation loss: 1.465 Validation accuracy: 99.61% times: 463.9851632118225
# test accuracy: 100.00
# Epoch cycle: 69 Training loss: 1.464 Validation loss: 1.474 Validation accuracy: 98.83% times: 470.8288562297821
# test accuracy: 99.22
# Epoch cycle: 70 Training loss: 1.464 Validation loss: 1.470 Validation accuracy: 99.22% times: 477.67300724983215
# test accuracy: 99.22
# Epoch cycle: 71 Training loss: 1.464 Validation loss: 1.473 Validation accuracy: 98.83% times: 484.50681948661804
# test accuracy: 100.00
# Epoch cycle: 72 Training loss: 1.464 Validation loss: 1.472 Validation accuracy: 99.22% times: 491.3422803878784
# test accuracy: 98.83
# Epoch cycle: 73 Training loss: 1.464 Validation loss: 1.479 Validation accuracy: 98.05% times: 498.1751992702484
# test accuracy: 99.61
# Epoch cycle: 74 Training loss: 1.464 Validation loss: 1.466 Validation accuracy: 99.61% times: 505.00922298431396
# test accuracy: 98.83
# Epoch cycle: 75 Training loss: 1.464 Validation loss: 1.468 Validation accuracy: 99.22% times: 511.8576409816742
# test accuracy: 99.22
# Epoch cycle: 76 Training loss: 1.464 Validation loss: 1.464 Validation accuracy: 100.00% times: 518.708559513092
# test accuracy: 99.61
# Epoch cycle: 77 Training loss: 1.464 Validation loss: 1.478 Validation accuracy: 98.05% times: 525.5418148040771
# test accuracy: 100.00
# Epoch cycle: 78 Training loss: 1.464 Validation loss: 1.472 Validation accuracy: 98.83% times: 532.3772687911987
# test accuracy: 99.61
# Epoch cycle: 79 Training loss: 1.464 Validation loss: 1.471 Validation accuracy: 98.44% times: 539.2102355957031
# test accuracy: 100.00
# Epoch cycle: 80 Training loss: 1.464 Validation loss: 1.464 Validation accuracy: 100.00% times: 546.0443155765533
# test accuracy: 99.61
# Epoch cycle: 81 Training loss: 1.464 Validation loss: 1.469 Validation accuracy: 99.22% times: 552.8920805454254
# test accuracy: 98.83
# Epoch cycle: 82 Training loss: 1.464 Validation loss: 1.474 Validation accuracy: 98.83% times: 559.7507545948029
# test accuracy: 99.61
# Epoch cycle: 83 Training loss: 1.464 Validation loss: 1.473 Validation accuracy: 98.83% times: 566.5931627750397
# test accuracy: 100.00
# Epoch cycle: 84 Training loss: 1.464 Validation loss: 1.469 Validation accuracy: 99.22% times: 573.4432897567749
# test accuracy: 99.22
# Epoch cycle: 85 Training loss: 1.464 Validation loss: 1.470 Validation accuracy: 99.22% times: 580.3051664829254
# test accuracy: 98.83
# Epoch cycle: 86 Training loss: 1.464 Validation loss: 1.474 Validation accuracy: 98.83% times: 587.1443960666656
# test accuracy: 99.22
# Epoch cycle: 87 Training loss: 1.463 Validation loss: 1.475 Validation accuracy: 98.83% times: 593.9990329742432
# test accuracy: 98.83
# Epoch cycle: 88 Training loss: 1.464 Validation loss: 1.464 Validation accuracy: 99.61% times: 600.860773563385
# test accuracy: 100.00
# Epoch cycle: 89 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 607.6961464881897
# test accuracy: 100.00
# Epoch cycle: 90 Training loss: 1.463 Validation loss: 1.463 Validation accuracy: 100.00% times: 614.545905828476
# test accuracy: 98.05
# Epoch cycle: 91 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 621.3788595199585
# test accuracy: 99.22
# Epoch cycle: 92 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 628.2302763462067
# test accuracy: 99.61
# Epoch cycle: 93 Training loss: 1.463 Validation loss: 1.475 Validation accuracy: 98.83% times: 635.0802044868469
# test accuracy: 100.00
# Epoch cycle: 94 Training loss: 1.463 Validation loss: 1.475 Validation accuracy: 98.44% times: 641.9308488368988
# test accuracy: 99.61
# Epoch cycle: 95 Training loss: 1.463 Validation loss: 1.470 Validation accuracy: 98.83% times: 648.7661130428314
# test accuracy: 99.22
# Epoch cycle: 96 Training loss: 1.463 Validation loss: 1.479 Validation accuracy: 98.44% times: 655.5976736545563
# test accuracy: 99.22
# Epoch cycle: 97 Training loss: 1.463 Validation loss: 1.470 Validation accuracy: 99.22% times: 662.4481921195984
# test accuracy: 100.00
# Epoch cycle: 98 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 669.3145453929901
# test accuracy: 98.83
# Epoch cycle: 99 Training loss: 1.463 Validation loss: 1.463 Validation accuracy: 100.00% times: 676.1647880077362
# test accuracy: 98.83
# Epoch cycle: 100 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 682.9989256858826
# test accuracy: 98.83
# Epoch cycle: 101 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 689.848584651947
# test accuracy: 98.83
# Epoch cycle: 102 Training loss: 1.463 Validation loss: 1.469 Validation accuracy: 99.22% times: 696.6987726688385
# test accuracy: 99.22
# Epoch cycle: 103 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 703.5503675937653
# test accuracy: 99.61
# Epoch cycle: 104 Training loss: 1.463 Validation loss: 1.476 Validation accuracy: 98.83% times: 710.3899435997009
# test accuracy: 99.61
# Epoch cycle: 105 Training loss: 1.463 Validation loss: 1.461 Validation accuracy: 100.00% times: 717.2489631175995
# test accuracy: 99.22
# Epoch cycle: 106 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 724.0995275974274
# test accuracy: 99.61
# Epoch cycle: 107 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 730.9506771564484
# test accuracy: 98.83
# Epoch cycle: 108 Training loss: 1.463 Validation loss: 1.483 Validation accuracy: 97.66% times: 737.6916613578796
# test accuracy: 99.22
# Epoch cycle: 109 Training loss: 1.463 Validation loss: 1.468 Validation accuracy: 99.22% times: 744.5357084274292
# test accuracy: 99.22
# Epoch cycle: 110 Training loss: 1.463 Validation loss: 1.479 Validation accuracy: 98.05% times: 751.3699407577515
# test accuracy: 99.22
# Epoch cycle: 111 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 758.2188682556152
# test accuracy: 99.61
# Epoch cycle: 112 Training loss: 1.463 Validation loss: 1.474 Validation accuracy: 98.83% times: 765.0523517131805
# test accuracy: 99.61
# Epoch cycle: 113 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 771.8901534080505
# test accuracy: 99.61
# Epoch cycle: 114 Training loss: 1.463 Validation loss: 1.468 Validation accuracy: 99.22% times: 778.7364349365234
# test accuracy: 99.22
# Epoch cycle: 115 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 785.5882279872894
# test accuracy: 99.22
# Epoch cycle: 116 Training loss: 1.463 Validation loss: 1.471 Validation accuracy: 99.22% times: 792.4376847743988
# test accuracy: 99.22
# Epoch cycle: 117 Training loss: 1.463 Validation loss: 1.479 Validation accuracy: 98.44% times: 799.2867424488068
# test accuracy: 99.22
# Epoch cycle: 118 Training loss: 1.463 Validation loss: 1.468 Validation accuracy: 99.22% times: 806.1209833621979
# test accuracy: 99.61
# Epoch cycle: 119 Training loss: 1.463 Validation loss: 1.461 Validation accuracy: 100.00% times: 812.9717843532562
# test accuracy: 99.61
# Epoch cycle: 120 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 819.8310248851776
# test accuracy: 100.00
# Epoch cycle: 121 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 826.6718919277191
# test accuracy: 99.22
# Epoch cycle: 122 Training loss: 1.463 Validation loss: 1.475 Validation accuracy: 98.44% times: 833.507616519928
# test accuracy: 99.22
# Epoch cycle: 123 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 840.3556900024414
# test accuracy: 99.61
# Epoch cycle: 124 Training loss: 1.463 Validation loss: 1.463 Validation accuracy: 100.00% times: 847.1898739337921
# test accuracy: 99.22
# Epoch cycle: 125 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 854.0243983268738
# test accuracy: 99.61
# Epoch cycle: 126 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 860.8754618167877
# test accuracy: 98.44
# Epoch cycle: 127 Training loss: 1.463 Validation loss: 1.471 Validation accuracy: 98.83% times: 867.7248985767365
# test accuracy: 99.22
# Epoch cycle: 128 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 874.573324918747
# test accuracy: 99.61
# Epoch cycle: 129 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 881.4237332344055
# test accuracy: 98.44
# Epoch cycle: 130 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 888.2500660419464
# test accuracy: 98.05
# Epoch cycle: 131 Training loss: 1.463 Validation loss: 1.461 Validation accuracy: 100.00% times: 895.0913805961609
# test accuracy: 98.44
# Epoch cycle: 132 Training loss: 1.462 Validation loss: 1.477 Validation accuracy: 98.44% times: 901.9570586681366
# test accuracy: 98.44
# Epoch cycle: 133 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 908.7913682460785
# test accuracy: 99.61
# Epoch cycle: 134 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 915.6245820522308
# test accuracy: 98.83
# Epoch cycle: 135 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 922.4743688106537
# test accuracy: 99.61
# Epoch cycle: 136 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 929.3251388072968
# test accuracy: 98.44
# Epoch cycle: 137 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 936.1603996753693
# test accuracy: 99.22
# Epoch cycle: 138 Training loss: 1.463 Validation loss: 1.464 Validation accuracy: 99.61% times: 943.011953830719
# test accuracy: 98.83
# Epoch cycle: 139 Training loss: 1.463 Validation loss: 1.468 Validation accuracy: 99.61% times: 949.8597180843353
# test accuracy: 99.22
# Epoch cycle: 140 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 956.7260982990265
# test accuracy: 99.61
# Epoch cycle: 141 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 963.5610406398773
# test accuracy: 99.22
# Epoch cycle: 142 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 970.4116852283478
# test accuracy: 99.22
# Epoch cycle: 143 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 977.2652592658997
# test accuracy: 98.83
# Epoch cycle: 144 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 984.1116764545441
# test accuracy: 100.00
# Epoch cycle: 145 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 990.9457061290741
# test accuracy: 98.83
# Epoch cycle: 146 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.22% times: 997.7973525524139
# test accuracy: 98.83
# Epoch cycle: 147 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1004.6495959758759
# test accuracy: 100.00
# Epoch cycle: 148 Training loss: 1.462 Validation loss: 1.464 Validation accuracy: 99.61% times: 1011.488422870636
# test accuracy: 98.83
# Epoch cycle: 149 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1018.3463432788849
# test accuracy: 98.83
# Epoch cycle: 150 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1025.18199467659
# test accuracy: 100.00
# Epoch cycle: 151 Training loss: 1.462 Validation loss: 1.487 Validation accuracy: 97.27% times: 1032.0127806663513
# test accuracy: 99.61
# Epoch cycle: 152 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1038.8636350631714
# test accuracy: 99.22
# Epoch cycle: 153 Training loss: 1.462 Validation loss: 1.477 Validation accuracy: 98.44% times: 1045.7133212089539
# test accuracy: 98.44
# Epoch cycle: 154 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1052.5503551959991
# test accuracy: 99.61
# Epoch cycle: 155 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1059.4039714336395
# test accuracy: 98.83
# Epoch cycle: 156 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1066.249345779419
# test accuracy: 98.83
# Epoch cycle: 157 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1073.0824933052063
# test accuracy: 99.61
# Epoch cycle: 158 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1079.9318618774414
# test accuracy: 98.83
# Epoch cycle: 159 Training loss: 1.462 Validation loss: 1.475 Validation accuracy: 98.44% times: 1086.7677891254425
# test accuracy: 99.22
# Epoch cycle: 160 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1093.616111755371
# test accuracy: 100.00
# Epoch cycle: 161 Training loss: 1.462 Validation loss: 1.471 Validation accuracy: 99.22% times: 1100.4530816078186
# test accuracy: 99.61
# Epoch cycle: 162 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 1107.2992281913757
# test accuracy: 99.22
# Epoch cycle: 163 Training loss: 1.462 Validation loss: 1.481 Validation accuracy: 98.05% times: 1114.1343126296997
# test accuracy: 97.27
# Epoch cycle: 164 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1120.9833035469055
# test accuracy: 99.22
# Epoch cycle: 165 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1127.82737159729
# test accuracy: 99.61
# Epoch cycle: 166 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1134.683448791504
# test accuracy: 99.22
# Epoch cycle: 167 Training loss: 1.462 Validation loss: 1.463 Validation accuracy: 99.61% times: 1141.5342195034027
# test accuracy: 99.61
# Epoch cycle: 168 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1148.3687357902527
# test accuracy: 100.00
# Epoch cycle: 169 Training loss: 1.462 Validation loss: 1.467 Validation accuracy: 99.61% times: 1155.2197015285492
# test accuracy: 98.83
# Epoch cycle: 170 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1162.067884683609
# test accuracy: 98.83
# Epoch cycle: 171 Training loss: 1.462 Validation loss: 1.475 Validation accuracy: 98.44% times: 1168.9026765823364
# test accuracy: 97.27
# Epoch cycle: 172 Training loss: 1.462 Validation loss: 1.475 Validation accuracy: 98.83% times: 1175.7523016929626
# test accuracy: 100.00
# Epoch cycle: 173 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1182.598473072052
# test accuracy: 100.00
# Epoch cycle: 174 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1189.4375982284546
# test accuracy: 99.61
# Epoch cycle: 175 Training loss: 1.463 Validation loss: 1.461 Validation accuracy: 100.00% times: 1196.345446586609
# test accuracy: 99.61
# Epoch cycle: 176 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1203.189932346344
# test accuracy: 99.61
# Epoch cycle: 177 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1210.0366473197937
# test accuracy: 98.44
# Epoch cycle: 178 Training loss: 1.462 Validation loss: 1.467 Validation accuracy: 99.61% times: 1216.8911619186401
# test accuracy: 98.05
# Epoch cycle: 179 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1223.7382836341858
# test accuracy: 98.83
# Epoch cycle: 180 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1230.5728528499603
# test accuracy: 100.00
# Epoch cycle: 181 Training loss: 1.462 Validation loss: 1.475 Validation accuracy: 98.44% times: 1237.4212884902954
# test accuracy: 100.00
# Epoch cycle: 182 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1244.2712833881378
# test accuracy: 100.00
# Epoch cycle: 183 Training loss: 1.462 Validation loss: 1.478 Validation accuracy: 98.44% times: 1251.1097338199615
# test accuracy: 98.83
# Epoch cycle: 184 Training loss: 1.462 Validation loss: 1.475 Validation accuracy: 98.44% times: 1257.9721703529358
# test accuracy: 99.61
# Epoch cycle: 185 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1264.8239648342133
# test accuracy: 99.61
# Epoch cycle: 186 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1271.672752380371
# test accuracy: 99.22
# Epoch cycle: 187 Training loss: 1.462 Validation loss: 1.474 Validation accuracy: 98.83% times: 1278.5143148899078
# test accuracy: 99.22
# Epoch cycle: 188 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1285.3729758262634
# test accuracy: 98.83
# Epoch cycle: 189 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1292.2077116966248
# test accuracy: 98.05
# Epoch cycle: 190 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1299.0688788890839
# test accuracy: 99.22
# Epoch cycle: 191 Training loss: 1.462 Validation loss: 1.482 Validation accuracy: 98.05% times: 1305.9320695400238
# test accuracy: 99.22
# Epoch cycle: 192 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1312.7818224430084
# test accuracy: 99.61
# Epoch cycle: 193 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1319.6246228218079
# test accuracy: 99.61
# Epoch cycle: 194 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1326.4590787887573
# test accuracy: 99.61
# Epoch cycle: 195 Training loss: 1.462 Validation loss: 1.464 Validation accuracy: 99.61% times: 1333.2937695980072
# test accuracy: 100.00
# Epoch cycle: 196 Training loss: 1.462 Validation loss: 1.471 Validation accuracy: 99.22% times: 1340.1422410011292
# test accuracy: 98.44
# Epoch cycle: 197 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1346.9775683879852
# test accuracy: 98.83
# Epoch cycle: 198 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1353.8276472091675
# test accuracy: 98.83
# Epoch cycle: 199 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1360.676632642746
# test accuracy: 99.61
# Epoch cycle: 200 Training loss: 1.462 Validation loss: 1.481 Validation accuracy: 98.05% times: 1367.53174161911
# test accuracy: 99.61
# Epoch cycle: 201 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1374.3780686855316
# test accuracy: 99.22
# Epoch cycle: 202 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1381.227417230606
# test accuracy: 99.22
# Epoch cycle: 203 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1388.0775001049042
# test accuracy: 99.22
# Epoch cycle: 204 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1394.9280593395233
# test accuracy: 99.22
# Epoch cycle: 205 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1401.7660393714905
# test accuracy: 99.22
# Epoch cycle: 206 Training loss: 1.462 Validation loss: 1.472 Validation accuracy: 98.83% times: 1408.6284947395325
# test accuracy: 98.83
# Epoch cycle: 207 Training loss: 1.462 Validation loss: 1.471 Validation accuracy: 98.83% times: 1415.4636430740356
# test accuracy: 98.44
# Epoch cycle: 208 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1422.3240704536438
# test accuracy: 98.83
# Epoch cycle: 209 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1429.1719632148743
# test accuracy: 99.61
# Epoch cycle: 210 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1436.0141925811768
# test accuracy: 98.83
# Epoch cycle: 211 Training loss: 1.462 Validation loss: 1.463 Validation accuracy: 99.61% times: 1442.8651158809662
# test accuracy: 99.61
# Epoch cycle: 212 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1449.7299745082855
# test accuracy: 99.22
# Epoch cycle: 213 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1456.5644483566284
# test accuracy: 99.22
# Epoch cycle: 214 Training loss: 1.462 Validation loss: 1.479 Validation accuracy: 98.44% times: 1463.4148337841034
# test accuracy: 98.83
# Epoch cycle: 215 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1470.2656042575836
# test accuracy: 99.61
# Epoch cycle: 216 Training loss: 1.462 Validation loss: 1.481 Validation accuracy: 98.05% times: 1477.1144630908966
# test accuracy: 98.44
# Epoch cycle: 217 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1483.9651410579681
# test accuracy: 99.61
# Epoch cycle: 218 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1490.8002936840057
# test accuracy: 98.83
# Epoch cycle: 219 Training loss: 1.462 Validation loss: 1.464 Validation accuracy: 99.61% times: 1497.665889263153
# test accuracy: 99.61
# Epoch cycle: 220 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1504.5163724422455
# test accuracy: 99.22
# Epoch cycle: 221 Training loss: 1.462 Validation loss: 1.471 Validation accuracy: 98.83% times: 1511.3499236106873
# test accuracy: 100.00
# Epoch cycle: 222 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1518.1862170696259
# test accuracy: 98.44
# Epoch cycle: 223 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1525.0501008033752
# test accuracy: 98.83
# Epoch cycle: 224 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1531.8839321136475
# test accuracy: 98.83
# Epoch cycle: 225 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1538.7514820098877
# test accuracy: 99.22
# Epoch cycle: 226 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1545.5875797271729
# test accuracy: 100.00
# Epoch cycle: 227 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1552.4385352134705
# test accuracy: 98.05
# Epoch cycle: 228 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1559.287035703659
# test accuracy: 99.22
# Epoch cycle: 229 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1566.136218547821
# test accuracy: 100.00
# Epoch cycle: 230 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1572.9872195720673
# test accuracy: 99.22
# Epoch cycle: 231 Training loss: 1.462 Validation loss: 1.464 Validation accuracy: 99.61% times: 1579.8432114124298
# test accuracy: 99.61
# Epoch cycle: 232 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1586.6876146793365
# test accuracy: 99.22
# Epoch cycle: 233 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1593.5375893115997
# test accuracy: 99.22
# Epoch cycle: 234 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1600.3893067836761
# test accuracy: 98.83
# Epoch cycle: 235 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1607.2333478927612
# test accuracy: 100.00
# Epoch cycle: 236 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1614.0905723571777
# test accuracy: 98.44
# Epoch cycle: 237 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1620.9383385181427
# test accuracy: 99.22
# Epoch cycle: 238 Training loss: 1.462 Validation loss: 1.474 Validation accuracy: 98.83% times: 1627.789077758789
# test accuracy: 99.61
# Epoch cycle: 239 Training loss: 1.462 Validation loss: 1.477 Validation accuracy: 98.44% times: 1634.6393692493439
# test accuracy: 98.83
# Epoch cycle: 240 Training loss: 1.462 Validation loss: 1.462 Validation accuracy: 100.00% times: 1641.489249944687
# test accuracy: 99.22
# Epoch cycle: 241 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1648.3406670093536
# test accuracy: 99.22
# Epoch cycle: 242 Training loss: 1.462 Validation loss: 1.467 Validation accuracy: 99.61% times: 1655.1896965503693
# test accuracy: 99.61
# Epoch cycle: 243 Training loss: 1.462 Validation loss: 1.463 Validation accuracy: 100.00% times: 1662.0540072917938
# test accuracy: 99.22
# Epoch cycle: 244 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1668.9058585166931
# test accuracy: 99.61
# Epoch cycle: 245 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1675.7571995258331
# test accuracy: 99.61
# Epoch cycle: 246 Training loss: 1.462 Validation loss: 1.476 Validation accuracy: 98.44% times: 1682.5909252166748
# test accuracy: 100.00
# Epoch cycle: 247 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1689.4257736206055
# test accuracy: 98.83
# Epoch cycle: 248 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1696.2760508060455
# test accuracy: 98.83
# Epoch cycle: 249 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1703.1255791187286
# test accuracy: 98.44
# Epoch cycle: 250 Training loss: 1.462 Validation loss: 1.476 Validation accuracy: 98.44% times: 1709.9743235111237
# test accuracy: 99.61
# Epoch cycle: 251 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1716.8250179290771
# test accuracy: 99.61
# Epoch cycle: 252 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1723.6591868400574
# test accuracy: 99.61
# Epoch cycle: 253 Training loss: 1.462 Validation loss: 1.479 Validation accuracy: 98.05% times: 1730.500286579132
# test accuracy: 99.61
# Epoch cycle: 254 Training loss: 1.462 Validation loss: 1.480 Validation accuracy: 98.05% times: 1737.342833518982
# test accuracy: 99.61
# Epoch cycle: 255 Training loss: 1.462 Validation loss: 1.467 Validation accuracy: 99.61% times: 1744.1929910182953
# test accuracy: 99.61
# Epoch cycle: 256 Training loss: 1.462 Validation loss: 1.461 Validation accuracy: 100.00% times: 1751.043650150299
# test accuracy: 98.83
# Epoch cycle: 257 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1757.8930988311768
# test accuracy: 99.22
# Epoch cycle: 258 Training loss: 1.462 Validation loss: 1.476 Validation accuracy: 98.44% times: 1764.7434995174408
# test accuracy: 99.22
# Epoch cycle: 259 Training loss: 1.462 Validation loss: 1.464 Validation accuracy: 99.61% times: 1771.5935096740723
# test accuracy: 98.83
# Epoch cycle: 260 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1778.4492168426514
# test accuracy: 99.61
# Epoch cycle: 261 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1785.2947645187378
# test accuracy: 99.22
# Epoch cycle: 262 Training loss: 1.462 Validation loss: 1.471 Validation accuracy: 98.83% times: 1792.1459834575653
# test accuracy: 99.22
# Epoch cycle: 263 Training loss: 1.462 Validation loss: 1.468 Validation accuracy: 99.22% times: 1799.0527620315552
# test accuracy: 99.22
# Epoch cycle: 264 Training loss: 1.462 Validation loss: 1.465 Validation accuracy: 99.61% times: 1805.8963255882263
# test accuracy: 100.00
# Epoch cycle: 265 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1812.7450637817383
# test accuracy: 100.00
# Epoch cycle: 266 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1819.5961105823517
# test accuracy: 99.22
# Epoch cycle: 267 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1826.6081738471985
# test accuracy: 99.61
# Epoch cycle: 268 Training loss: 1.462 Validation loss: 1.466 Validation accuracy: 99.61% times: 1833.4692208766937
# test accuracy: 99.22
# Epoch cycle: 269 Training loss: 1.462 Validation loss: 1.473 Validation accuracy: 98.83% times: 1840.3541822433472
# test accuracy: 99.22
# Epoch cycle: 270 Training loss: 1.462 Validation loss: 1.480 Validation accuracy: 98.05% times: 1847.2914323806763
# test accuracy: 100.00
# Epoch cycle: 271 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1854.206042289734
# test accuracy: 98.83
# Epoch cycle: 272 Training loss: 1.462 Validation loss: 1.470 Validation accuracy: 99.22% times: 1861.1211321353912
# test accuracy: 100.00
# Epoch cycle: 273 Training loss: 1.462 Validation loss: 1.469 Validation accuracy: 99.22% times: 1867.9951519966125
# test accuracy: 99.61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-528ccb1175bf> in <module>()
#      93         input_batch, target_batch = mnist.train.next_batch(batch_num)
#      94         _,batch_loss,train_accuracy = sess.run([optimizer,loss,accuracy],
# ---> 95                                 feed_dict={inputs:input_batch,targets: target_batch,keep_prop:0.5})
#      96         curr_epoc_loss += batch_loss
#      97     curr_epoc_loss/=batch_cycle_a
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# 99.22% Learning_rate:0.0001 batch:128 Keep_prop:0.5/0.5/1
# 99.33% Learning_rate:0.0003 batch:256 Keep_prop:0.5/0.8/1

# %%
# save prediction

#---------------------------------------------------------------#
import pandas as pd

test_df = pd.read_csv('test.csv')
X = test_df.values
print('特征矩阵的形状：', X.shape)
X1 = X[:1000]
X2 = X[1000:2000]
X3 = X[2000:3000]
X4 = X[3000:4000]
X5 = X[4000:5000]
X6 = X[5000:6000]
X7 = X[6000:7000]
X8 = X[7000:8000]
X9 = X[8000:9000]
X10 = X[9000:10000]
X11 = X[10000:11000]
X12 = X[11000:12000]
X13 = X[12000:13000]
X14 = X[13000:14000]
X15 = X[14000:15000]
X16 = X[15000:16000]
X17 = X[16000:17000]
X18 = X[17000:18000]
X19 = X[18000:19000]
X20 = X[19000:20000]
X21 = X[20000:21000]
X22 = X[21000:22000]
X23 = X[22000:23000]
X24 = X[23000:24000]
X25 = X[24000:25000]
X26 = X[25000:26000]
X27 = X[26000:27000]
X28 = X[27000:]

y1 = sess.run(outputs, feed_dict={inputs:X1,keep_prop:1})
y2 = sess.run(outputs, feed_dict={inputs:X2,keep_prop:1})
y3 = sess.run(outputs, feed_dict={inputs:X3,keep_prop:1})
y4 = sess.run(outputs, feed_dict={inputs:X4,keep_prop:1})
y5 = sess.run(outputs, feed_dict={inputs:X5,keep_prop:1})
y6 = sess.run(outputs, feed_dict={inputs:X6,keep_prop:1})
y7 = sess.run(outputs, feed_dict={inputs:X7,keep_prop:1})
y8 = sess.run(outputs, feed_dict={inputs:X8,keep_prop:1})
y9 = sess.run(outputs, feed_dict={inputs:X9,keep_prop:1})
y10 = sess.run(outputs, feed_dict={inputs:X10,keep_prop:1})
y11 = sess.run(outputs, feed_dict={inputs:X11,keep_prop:1})
y12 = sess.run(outputs, feed_dict={inputs:X12,keep_prop:1})
y13 = sess.run(outputs, feed_dict={inputs:X13,keep_prop:1})
y14 = sess.run(outputs, feed_dict={inputs:X14,keep_prop:1})
y15 = sess.run(outputs, feed_dict={inputs:X15,keep_prop:1})
y16 = sess.run(outputs, feed_dict={inputs:X16,keep_prop:1})
y17 = sess.run(outputs, feed_dict={inputs:X17,keep_prop:1})
y18 = sess.run(outputs, feed_dict={inputs:X18,keep_prop:1})
y19 = sess.run(outputs, feed_dict={inputs:X19,keep_prop:1})
y20 = sess.run(outputs, feed_dict={inputs:X20,keep_prop:1})
y21 = sess.run(outputs, feed_dict={inputs:X21,keep_prop:1})
y22 = sess.run(outputs, feed_dict={inputs:X22,keep_prop:1})
y23 = sess.run(outputs, feed_dict={inputs:X23,keep_prop:1})
y24 = sess.run(outputs, feed_dict={inputs:X24,keep_prop:1})
y25 = sess.run(outputs, feed_dict={inputs:X25,keep_prop:1})
y26 = sess.run(outputs, feed_dict={inputs:X26,keep_prop:1})
y27 = sess.run(outputs, feed_dict={inputs:X27,keep_prop:1})
y28 = sess.run(outputs, feed_dict={inputs:X28,keep_prop:1})
import numpy as np
y = np.vstack([y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, y11, y12, y13, y14, y15, y16, y17, y18, y19, y20, y21, y22, y23, y24, y25, y26, y27, y28])
y_argmax = np.argmax(y, 1)
y_argmax.shape
print('预测值的形状：', y_argmax.shape)
commit_df = pd.DataFrame({'ImageId': range(1, 1+len(y_argmax)),
                         'Label': y_argmax})
fileName = 'kaggle_commit.csv'
commit_df.to_csv(fileName, index=False)
print('预测结果已经保存到文件', fileName)
# Out:
# 特征矩阵的形状： (28000, 784)
# 预测值的形状： (28000,)
# 预测结果已经保存到文件 kaggle_commit.csv

# %%
#---------------------------------------------施工中-------------------------------------------------------------#
#CNN model

import numpy as np
import tensorflow as tf

def weight_variable(shape):
    initializer = tf.contrib.layers.xavier_initializer()
    return tf.get_variable('weight',shape,initializer=initializer,dtype=tf.float32)

def bias_variable(shape):
    initialier = tf.constance_initializer()
    return tf.get_variable('bias',shape,initializer=initializer,dtype=tf.float32)

def conv2d(inputs, w):
    return tf.nn.conv2d(inputs,w,strides = [1,1,1,1],padding = 'SAME')

def max_pooling_2x2(inputs,x=2,y=2):
    ksize = [1,x,y,1]
    return tf.nn.max_pool(inputs,ksize,strides = [1,2,2,1],padding = 'SAME')

class MNISTcnn(object):
    def __init__(self,inputs,targets,conf):
        self.inputs = inputs
        self.targets = targets
        self.keep_drop = tf.palceholder(tf.float32)
        
        # 1st layer
        with tf.variable_scope(conv1):
            W_conv1 = weight_variable([5, 5, 1, 32])
            b_conv1 = bias_variable([32])
            h_conv1 = tf.nn.relu(conv2d(self.inputs, W_conv1) + b_conv1)
            h_pool1 = max_pool_2x2(h_conv1)
        # 2nd layer
        with tf.variable__scope(conv2):
            W_conv2 = weight_variable([5, 5, 32, 64])
            b_conv2 = bias_variable([64])
            h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
            h_pool2 = max_pool_2x2(h_conv2)
        #fully connected 1st layer
        with tf.variable_scope("fc1"):
            shape = int(np.prod(h_pool2.get_shape()[1:]))
            W_fc1 = weight_variable([shape, 1024])
            b_fc1 = bias_variable([1024])
            h_pool2_flat = tf.reshape(h_pool2, [-1, shape])
            h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)
        # dropout
        h_fc1_drop = tf.nn.dropout(h_fc1, self.keep_prob)
        #fully connected to outputs
        with tf.variable_scope("fc2"):
            W_fc2 = weight_variable([1024, 10])
            b_fc2 = bias_variable([10])
            outputs = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

        self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=self.targets, logits=outputs))
        self.pred = tf.argmax(outputs, 1)

        self.correct_prediction = tf.equal(tf.argmax(outputs,1), tf.argmax(self.targets,1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
