# %% [markdown]
# # MNIST by Convolution NN (LeNet-5)
# * 2 conv([5,5],64) 2 maxpooling(strides=2) FC(1024)
# * input=[batch,length,width,deep]
# * Convolution kernel(w) = [length,width,deep_in,deep_out]
# * strides = [1,step,step,1]
# * new_height = new_width = (input — kernel + 1) / Strides

# %%
#import data and library
import numpy as np
import pandas as pd 
import tensorflow as tf
import random
from tensorflow.examples.tutorials.mnist import input_data
old_v = tf.logging.get_verbosity()
tf.logging.set_verbosity(tf.logging.ERROR)

mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)

train_data = mnist.train.images  # Returns np.array
train_labels = np.asarray(mnist.train.labels, dtype=np.int32)
test_data = mnist.test.images  # Returns np.array
test_labels = np.asarray(mnist.test.labels, dtype=np.int32)

tf.logging.set_verbosity(old_v)
# Out:
# E:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#def feature map and pooling


def weight_variable(name,shape):
    initializer = tf.contrib.layers.xavier_initializer(seed=1)
    return tf.get_variable(name,shape,initializer=initializer,dtype=tf.float32)

def bias_variable(name,shape):
    return tf.get_variable(name, shape)

def conv2d(inputs, w):
    return tf.nn.conv2d(inputs,w,strides = [1,1,1,1],padding = 'SAME')

def max_pooling_2x2(inputs,x=2,y=2):
    ksize = [1,x,y,1]
    return tf.nn.max_pool(inputs,ksize,strides = [1,2,2,1],padding = 'SAME')

# %%
#set outlines 
inputs_num = 784 # 28*28 =784  (784,1)
outputs_num = 10 # 0 to 9   

#reset variable in tensorflow
tf.reset_default_graph()

#stack data
X = np.vstack([mnist.train.images, mnist.test.images, mnist.validation.images])
y = np.vstack([mnist.train.labels, mnist.test.labels, mnist.validation.labels])

#set placeholder(input and target)
inputs= tf.placeholder(tf.float32,[None,inputs_num],)
targets= tf.placeholder(tf.float32,[None,outputs_num],)
#transfer image to 4D data([batch,in_height,in_width,in_channels])
inputs_image = tf.reshape(inputs,[-1,28,28,1])

#set 1st convolution layer w and b
w_conv1 = weight_variable('w_1',[5,5,1,32])
b_conv1 = bias_variable('b_1',[32])
#set 2nd convolution layer w and b
w_conv2 = weight_variable('w_2',[5,5,32,64])
b_conv2 = bias_variable('b_2',[64])

#convolution layer and max pooling (relu activation function) 2 times pooling 28 ->14 ->7
h_conv1 = tf.nn.relu(conv2d(inputs_image,w_conv1)+b_conv1)
h_pool1 = max_pooling_2x2(h_conv1)

h_conv2 = tf.nn.relu(conv2d(h_pool1,w_conv2)+b_conv2)
h_pool2 = max_pooling_2x2(h_conv2)

#set 1st fully connected variable(last layer 7*7*64, 1024 nuron)
fc_w1 = weight_variable('fc_w1',[7*7*64,1024])
fc_b1 = bias_variable('fc_b1',[1024])

#flatten
h_pool2_flatten = tf.reshape(h_pool2,[-1,7*7*64])

# fully connected 1
fc_1 = tf.nn.relu(tf.matmul(h_pool2_flatten,fc_w1)+fc_b1)

# dropout(testing need turn off)
keep_prop = tf.placeholder(tf.float32)
fc_1_drop = tf.nn.dropout(fc_1,keep_prop)

#set 2nd fully connected variable(last layer 1024, 10 nuron)
fc_w2 = weight_variable('fc_w2',[1024,10])
fc_b2 = bias_variable('fc_b2',[10])

#predicted outputs
outputs = tf.nn.softmax(tf.matmul(fc_1_drop,fc_w2)+fc_b2)

# set loss and optimize object
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=outputs, labels=targets))
# loss = tf.reduce_mean(-tf.reduce_sum(targets * tf.log(outputs), 1))
optimizer = tf.train.AdamOptimizer(learning_rate=0.0001,).minimize(loss)

#after softmax, let probability to 0 or 1 by argmax function, and judge between target and output
out_eql_target = tf.equal(tf.argmax(outputs,1), tf.argmax(targets,1))

#predicte accuracy (need cast to float32)
accuracy = tf.reduce_mean(tf.cast(out_eql_target,tf.float32))

#框架完成

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.4
# session = tf.Session(config=config)
#sess
sess= tf.InteractiveSession()

#initial variable
initializer = tf.global_variables_initializer()
sess.run(initializer)


#set training paramerter
epochs = 10000
batch_num = 256
batch_cycle_a = mnist.train._num_examples // batch_num
batch_cycle_b = mnist.validation._num_examples // batch_num
batch_cycle_c = mnist.test._num_examples // batch_num
prev_validation = 9999999.

#Training model
import time
start = time.time()
for epoch_counter in range(epochs):
    curr_epoc_loss = 0.
    curr_epoc_val = 0.
    curr_epoc_tes = 0.
    for batch_counter in range(batch_cycle_a):
        input_batch, target_batch = mnist.train.next_batch(batch_num)
        _,batch_loss,train_accuracy = sess.run([optimizer,loss,accuracy],
                                feed_dict={inputs:input_batch,targets: target_batch,keep_prop:0.5})
        curr_epoc_loss += batch_loss
    curr_epoc_loss/=batch_cycle_a
    # validation
    for batch_counter in range(batch_cycle_b):
        input_batch, target_batch = mnist.validation.next_batch(batch_num)
        val_loss, val_accuracy = sess.run([loss,accuracy],feed_dict={inputs:input_batch,targets:target_batch, keep_prop:0.5})
        curr_epoc_val += val_loss
    curr_epoc_val/=batch_cycle_b
#     if val_loss>prev_validation:
#         break
#     prev_validation = val_loss


    print(f'Epoch cycle: {epoch_counter + 1}'+
             f' Training loss: {curr_epoc_loss:.3f}'+
             f' Validation loss: {val_loss:.3f}'+
             f' Validation accuracy: {val_accuracy*100.:.2f}'+'%'+
             f' times: {time.time() - start}')
    
    
    for batch_counter in range(batch_cycle_c):
        input_batch, target_batch = mnist.test.next_batch(batch_num)
        test_accuracy = sess.run([accuracy],feed_dict ={inputs:input_batch,targets:target_batch,keep_prop:1})
    test_accuracy_percent=test_accuracy[0]*100.
    print(f'test accuracy: {test_accuracy_percent:.2f}')
    if  test_accuracy[0] > 0.997 and val_accuracy > 0.997:
        saver = tf.train.Saver()
        save_path = saver.save(sess, 'mnist_cnn_model/mnist_cnn.ckpt')
        print('Save to path:', save_path)
        break
print('end of training')
# Out:
# E:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Epoch cycle: 1 Training loss: 1.857 Validation loss: 1.597 Validation accuracy: 88.28% times: 6.499316692352295
# test accuracy: 90.23
# Epoch cycle: 2 Training loss: 1.565 Validation loss: 1.517 Validation accuracy: 96.09% times: 13.414217472076416
# test accuracy: 93.75
# Epoch cycle: 3 Training loss: 1.531 Validation loss: 1.513 Validation accuracy: 96.48% times: 20.34702777862549
# test accuracy: 95.31
# Epoch cycle: 4 Training loss: 1.512 Validation loss: 1.492 Validation accuracy: 97.66% times: 27.212347984313965
# test accuracy: 99.61
# Epoch cycle: 5 Training loss: 1.502 Validation loss: 1.498 Validation accuracy: 96.88% times: 34.066669940948486
# test accuracy: 96.09
# Epoch cycle: 6 Training loss: 1.495 Validation loss: 1.492 Validation accuracy: 96.88% times: 40.94104194641113
# test accuracy: 98.44
# Epoch cycle: 7 Training loss: 1.492 Validation loss: 1.488 Validation accuracy: 97.66% times: 47.81301951408386
# test accuracy: 98.44
# Epoch cycle: 8 Training loss: 1.488 Validation loss: 1.489 Validation accuracy: 96.88% times: 54.822280168533325
# test accuracy: 97.66
# Epoch cycle: 9 Training loss: 1.485 Validation loss: 1.475 Validation accuracy: 98.83% times: 61.70019173622131
# test accuracy: 98.44
# Epoch cycle: 10 Training loss: 1.484 Validation loss: 1.483 Validation accuracy: 98.05% times: 68.59880805015564
# test accuracy: 100.00
# Epoch cycle: 11 Training loss: 1.481 Validation loss: 1.475 Validation accuracy: 98.83% times: 75.47741270065308
# test accuracy: 96.48
# Epoch cycle: 12 Training loss: 1.480 Validation loss: 1.482 Validation accuracy: 98.05% times: 82.54993057250977
# test accuracy: 99.22
# Epoch cycle: 13 Training loss: 1.479 Validation loss: 1.484 Validation accuracy: 97.27% times: 89.74120211601257
# test accuracy: 99.22
# Epoch cycle: 14 Training loss: 1.478 Validation loss: 1.485 Validation accuracy: 97.66% times: 96.64591693878174
# test accuracy: 99.22
# Epoch cycle: 15 Training loss: 1.477 Validation loss: 1.480 Validation accuracy: 98.05% times: 103.51614379882812
# test accuracy: 98.83
# Epoch cycle: 16 Training loss: 1.476 Validation loss: 1.480 Validation accuracy: 98.44% times: 110.53860855102539
# test accuracy: 98.05
# Epoch cycle: 17 Training loss: 1.476 Validation loss: 1.474 Validation accuracy: 99.61% times: 117.64403104782104
# test accuracy: 98.44
# Epoch cycle: 18 Training loss: 1.475 Validation loss: 1.482 Validation accuracy: 98.05% times: 124.6915910243988
# test accuracy: 98.44
# Epoch cycle: 19 Training loss: 1.475 Validation loss: 1.477 Validation accuracy: 98.44% times: 131.7427031993866
# test accuracy: 99.22
# Epoch cycle: 20 Training loss: 1.473 Validation loss: 1.474 Validation accuracy: 98.83% times: 138.75834894180298
# test accuracy: 99.61
# Epoch cycle: 21 Training loss: 1.473 Validation loss: 1.477 Validation accuracy: 98.83% times: 145.7734830379486
# test accuracy: 97.66
# Epoch cycle: 22 Training loss: 1.472 Validation loss: 1.492 Validation accuracy: 96.48% times: 152.79704308509827
# test accuracy: 98.83
# Epoch cycle: 23 Training loss: 1.472 Validation loss: 1.488 Validation accuracy: 97.27% times: 159.81228065490723
# test accuracy: 99.22
# Epoch cycle: 24 Training loss: 1.472 Validation loss: 1.481 Validation accuracy: 98.05% times: 166.84611797332764
# test accuracy: 98.83
# Epoch cycle: 25 Training loss: 1.471 Validation loss: 1.475 Validation accuracy: 98.83% times: 173.87357211112976
# test accuracy: 99.61
# Epoch cycle: 26 Training loss: 1.471 Validation loss: 1.472 Validation accuracy: 99.22% times: 180.89747214317322
# test accuracy: 99.22
# Epoch cycle: 27 Training loss: 1.470 Validation loss: 1.466 Validation accuracy: 99.61% times: 187.91441655158997
# test accuracy: 98.83
# Epoch cycle: 28 Training loss: 1.470 Validation loss: 1.469 Validation accuracy: 99.22% times: 194.93029856681824
# test accuracy: 99.61
# Epoch cycle: 29 Training loss: 1.470 Validation loss: 1.482 Validation accuracy: 98.05% times: 201.9752333164215
# test accuracy: 98.83
# Epoch cycle: 30 Training loss: 1.469 Validation loss: 1.469 Validation accuracy: 99.22% times: 208.99621677398682
# test accuracy: 98.05
# Epoch cycle: 31 Training loss: 1.468 Validation loss: 1.476 Validation accuracy: 98.44% times: 216.02280712127686
# test accuracy: 100.00
# Epoch cycle: 32 Training loss: 1.468 Validation loss: 1.467 Validation accuracy: 99.61% times: 223.037011384964
# test accuracy: 99.22
# Epoch cycle: 33 Training loss: 1.469 Validation loss: 1.466 Validation accuracy: 100.00% times: 230.0545356273651
# test accuracy: 98.05
# Epoch cycle: 34 Training loss: 1.468 Validation loss: 1.466 Validation accuracy: 99.61% times: 237.06996488571167
# test accuracy: 99.61
# Epoch cycle: 35 Training loss: 1.468 Validation loss: 1.471 Validation accuracy: 99.22% times: 244.09443426132202
# test accuracy: 99.61
# Epoch cycle: 36 Training loss: 1.468 Validation loss: 1.471 Validation accuracy: 98.83% times: 251.12493681907654
# test accuracy: 98.83
# Epoch cycle: 37 Training loss: 1.467 Validation loss: 1.478 Validation accuracy: 98.44% times: 258.1709711551666
# test accuracy: 98.44
# Epoch cycle: 38 Training loss: 1.468 Validation loss: 1.463 Validation accuracy: 100.00% times: 265.2031219005585
# test accuracy: 99.61
# Epoch cycle: 39 Training loss: 1.467 Validation loss: 1.473 Validation accuracy: 98.83% times: 272.23372650146484
# test accuracy: 98.83
# Epoch cycle: 40 Training loss: 1.467 Validation loss: 1.464 Validation accuracy: 100.00% times: 279.2636113166809
# test accuracy: 98.83
# Epoch cycle: 41 Training loss: 1.467 Validation loss: 1.462 Validation accuracy: 100.00% times: 286.28796100616455
# test accuracy: 99.61
# Epoch cycle: 42 Training loss: 1.467 Validation loss: 1.470 Validation accuracy: 99.22% times: 293.31871223449707
# test accuracy: 98.83
# Epoch cycle: 43 Training loss: 1.466 Validation loss: 1.478 Validation accuracy: 98.44% times: 300.368266582489
# test accuracy: 99.61
# Epoch cycle: 44 Training loss: 1.466 Validation loss: 1.466 Validation accuracy: 99.61% times: 307.40121030807495
# test accuracy: 100.00
# Epoch cycle: 45 Training loss: 1.466 Validation loss: 1.471 Validation accuracy: 98.83% times: 314.4251058101654
# test accuracy: 99.22
# Epoch cycle: 46 Training loss: 1.466 Validation loss: 1.462 Validation accuracy: 100.00% times: 321.45489621162415
# test accuracy: 99.22
# Epoch cycle: 47 Training loss: 1.466 Validation loss: 1.480 Validation accuracy: 98.05% times: 328.4901702404022
# test accuracy: 98.83
# Epoch cycle: 48 Training loss: 1.465 Validation loss: 1.478 Validation accuracy: 98.05% times: 335.52280354499817
# test accuracy: 98.83
# Epoch cycle: 49 Training loss: 1.466 Validation loss: 1.463 Validation accuracy: 100.00% times: 342.55329275131226
# test accuracy: 98.44
# Epoch cycle: 50 Training loss: 1.465 Validation loss: 1.477 Validation accuracy: 98.44% times: 349.5865795612335
# test accuracy: 99.61
# Epoch cycle: 51 Training loss: 1.466 Validation loss: 1.468 Validation accuracy: 99.61% times: 356.61338782310486
# test accuracy: 99.61
# Epoch cycle: 52 Training loss: 1.465 Validation loss: 1.467 Validation accuracy: 99.61% times: 363.64932012557983
# test accuracy: 100.00
# Epoch cycle: 53 Training loss: 1.465 Validation loss: 1.477 Validation accuracy: 98.44% times: 370.68059635162354
# test accuracy: 100.00
# Epoch cycle: 54 Training loss: 1.465 Validation loss: 1.466 Validation accuracy: 99.61% times: 377.71538639068604
# test accuracy: 99.61
# Epoch cycle: 55 Training loss: 1.465 Validation loss: 1.470 Validation accuracy: 99.22% times: 384.7511897087097
# test accuracy: 98.83
# Epoch cycle: 56 Training loss: 1.465 Validation loss: 1.470 Validation accuracy: 99.22% times: 391.7802734375
# test accuracy: 100.00
# Epoch cycle: 57 Training loss: 1.465 Validation loss: 1.469 Validation accuracy: 99.22% times: 398.81625056266785
# test accuracy: 99.61
# Epoch cycle: 58 Training loss: 1.464 Validation loss: 1.471 Validation accuracy: 98.83% times: 405.8552222251892
# test accuracy: 99.22
# Epoch cycle: 59 Training loss: 1.465 Validation loss: 1.476 Validation accuracy: 98.44% times: 412.9020285606384
# test accuracy: 98.83
# Epoch cycle: 60 Training loss: 1.465 Validation loss: 1.470 Validation accuracy: 99.22% times: 419.9515063762665
# test accuracy: 99.61
# Epoch cycle: 61 Training loss: 1.464 Validation loss: 1.466 Validation accuracy: 99.61% times: 426.9936695098877
# test accuracy: 97.66
# Epoch cycle: 62 Training loss: 1.464 Validation loss: 1.467 Validation accuracy: 99.61% times: 434.043092250824
# test accuracy: 99.22
# Epoch cycle: 63 Training loss: 1.464 Validation loss: 1.465 Validation accuracy: 99.61% times: 441.0762026309967
# test accuracy: 99.61
# Epoch cycle: 64 Training loss: 1.464 Validation loss: 1.474 Validation accuracy: 98.83% times: 448.1054677963257
# test accuracy: 98.05
# Epoch cycle: 65 Training loss: 1.464 Validation loss: 1.468 Validation accuracy: 99.22% times: 455.16351318359375
# test accuracy: 100.00
# Epoch cycle: 66 Training loss: 1.464 Validation loss: 1.474 Validation accuracy: 98.44% times: 462.24549174308777
# test accuracy: 98.83
# Epoch cycle: 67 Training loss: 1.464 Validation loss: 1.476 Validation accuracy: 98.44% times: 469.28014183044434
# test accuracy: 99.22
# Epoch cycle: 68 Training loss: 1.464 Validation loss: 1.472 Validation accuracy: 98.83% times: 476.3112874031067
# test accuracy: 99.61
# Epoch cycle: 69 Training loss: 1.464 Validation loss: 1.471 Validation accuracy: 98.83% times: 483.3454041481018
# test accuracy: 100.00
# Epoch cycle: 70 Training loss: 1.464 Validation loss: 1.470 Validation accuracy: 99.22% times: 490.37821531295776
# test accuracy: 98.44
# Epoch cycle: 71 Training loss: 1.464 Validation loss: 1.475 Validation accuracy: 98.44% times: 497.4047899246216
# test accuracy: 99.61
# Epoch cycle: 72 Training loss: 1.464 Validation loss: 1.462 Validation accuracy: 100.00% times: 504.4426519870758
# test accuracy: 98.83
# Epoch cycle: 73 Training loss: 1.464 Validation loss: 1.461 Validation accuracy: 100.00% times: 511.49384808540344
# test accuracy: 99.61
# Epoch cycle: 74 Training loss: 1.464 Validation loss: 1.475 Validation accuracy: 98.83% times: 518.5412979125977
# test accuracy: 98.83
# Epoch cycle: 75 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 525.5849795341492
# test accuracy: 98.83
# Epoch cycle: 76 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 532.6244053840637
# test accuracy: 99.22
# Epoch cycle: 77 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 539.660409450531
# test accuracy: 100.00
# Epoch cycle: 78 Training loss: 1.463 Validation loss: 1.481 Validation accuracy: 98.05% times: 546.688978433609
# test accuracy: 99.61
# Epoch cycle: 79 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.22% times: 553.8028562068939
# test accuracy: 99.61
# Epoch cycle: 80 Training loss: 1.464 Validation loss: 1.469 Validation accuracy: 99.22% times: 560.8726804256439
# test accuracy: 100.00
# Epoch cycle: 81 Training loss: 1.463 Validation loss: 1.481 Validation accuracy: 98.05% times: 567.9503517150879
# test accuracy: 100.00
# Epoch cycle: 82 Training loss: 1.463 Validation loss: 1.464 Validation accuracy: 99.61% times: 574.997799873352
# test accuracy: 99.61
# Epoch cycle: 83 Training loss: 1.463 Validation loss: 1.469 Validation accuracy: 99.22% times: 582.036208152771
# test accuracy: 98.05
# Epoch cycle: 84 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 589.0975232124329
# test accuracy: 99.61
# Epoch cycle: 85 Training loss: 1.463 Validation loss: 1.482 Validation accuracy: 98.05% times: 596.1448652744293
# test accuracy: 99.61
# Epoch cycle: 86 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 603.1931929588318
# test accuracy: 97.66
# Epoch cycle: 87 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 610.2383861541748
# test accuracy: 99.22
# Epoch cycle: 88 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 617.2808992862701
# test accuracy: 99.61
# Epoch cycle: 89 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 624.3290324211121
# test accuracy: 99.22
# Epoch cycle: 90 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 631.3831143379211
# test accuracy: 99.22
# Epoch cycle: 91 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 638.4301085472107
# test accuracy: 98.05
# Epoch cycle: 92 Training loss: 1.463 Validation loss: 1.476 Validation accuracy: 98.44% times: 645.4875910282135
# test accuracy: 98.44
# Epoch cycle: 93 Training loss: 1.463 Validation loss: 1.470 Validation accuracy: 98.83% times: 652.5469784736633
# test accuracy: 99.61
# Epoch cycle: 94 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 659.5854756832123
# test accuracy: 99.22
# Epoch cycle: 95 Training loss: 1.463 Validation loss: 1.470 Validation accuracy: 99.22% times: 666.6366112232208
# test accuracy: 99.22
# Epoch cycle: 96 Training loss: 1.463 Validation loss: 1.477 Validation accuracy: 98.83% times: 673.69544506073
# test accuracy: 99.61
# Epoch cycle: 97 Training loss: 1.463 Validation loss: 1.469 Validation accuracy: 99.22% times: 680.747474193573
# test accuracy: 99.22
# Epoch cycle: 98 Training loss: 1.463 Validation loss: 1.463 Validation accuracy: 100.00% times: 687.7998394966125
# test accuracy: 99.22
# Epoch cycle: 99 Training loss: 1.463 Validation loss: 1.471 Validation accuracy: 99.22% times: 694.8461191654205
# test accuracy: 99.22
# Epoch cycle: 100 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 99.22% times: 701.7896430492401
# test accuracy: 99.22
# Epoch cycle: 101 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 708.840838432312
# test accuracy: 99.61
# Epoch cycle: 102 Training loss: 1.463 Validation loss: 1.480 Validation accuracy: 98.05% times: 715.8973684310913
# test accuracy: 99.22
# Epoch cycle: 103 Training loss: 1.463 Validation loss: 1.480 Validation accuracy: 98.05% times: 722.9467811584473
# test accuracy: 99.22
# Epoch cycle: 104 Training loss: 1.463 Validation loss: 1.463 Validation accuracy: 100.00% times: 730.00230717659
# test accuracy: 99.22
# Epoch cycle: 105 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 737.0560841560364
# test accuracy: 98.83
# Epoch cycle: 106 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 744.1080188751221
# test accuracy: 100.00
# Epoch cycle: 107 Training loss: 1.463 Validation loss: 1.470 Validation accuracy: 99.22% times: 751.1442294120789
# test accuracy: 98.83
# Epoch cycle: 108 Training loss: 1.463 Validation loss: 1.465 Validation accuracy: 99.61% times: 758.1710684299469
# test accuracy: 98.05
# Epoch cycle: 109 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 765.2020037174225
# test accuracy: 99.61
# Epoch cycle: 110 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 772.2406287193298
# test accuracy: 99.61
# Epoch cycle: 111 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 779.293922662735
# test accuracy: 99.61
# Epoch cycle: 112 Training loss: 1.463 Validation loss: 1.474 Validation accuracy: 98.83% times: 786.3500392436981
# test accuracy: 99.61
# Epoch cycle: 113 Training loss: 1.463 Validation loss: 1.469 Validation accuracy: 99.22% times: 793.4090557098389
# test accuracy: 100.00
# Epoch cycle: 114 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 99.61% times: 800.5013062953949
# test accuracy: 98.83
# Epoch cycle: 115 Training loss: 1.463 Validation loss: 1.468 Validation accuracy: 99.22% times: 807.5709209442139
# test accuracy: 98.44
# Epoch cycle: 116 Training loss: 1.463 Validation loss: 1.462 Validation accuracy: 100.00% times: 814.6126964092255
# test accuracy: 99.61
# Epoch cycle: 117 Training loss: 1.463 Validation loss: 1.481 Validation accuracy: 98.05% times: 821.6546657085419
# test accuracy: 98.44
# Epoch cycle: 118 Training loss: 1.463 Validation loss: 1.475 Validation accuracy: 98.44% times: 828.7086329460144
# test accuracy: 99.61
# Epoch cycle: 119 Training loss: 1.463 Validation loss: 1.479 Validation accuracy: 98.05% times: 835.7591774463654
# test accuracy: 98.83
# Epoch cycle: 120 Training loss: 1.463 Validation loss: 1.461 Validation accuracy: 100.00% times: 842.8053395748138
# test accuracy: 99.61
# Epoch cycle: 121 Training loss: 1.463 Validation loss: 1.472 Validation accuracy: 98.83% times: 849.8869986534119
# test accuracy: 100.00
# Epoch cycle: 122 Training loss: 1.463 Validation loss: 1.478 Validation accuracy: 98.05% times: 856.9435362815857
# test accuracy: 99.22
# Epoch cycle: 123 Training loss: 1.463 Validation loss: 1.473 Validation accuracy: 98.83% times: 864.0166194438934
# test accuracy: 99.61
# Epoch cycle: 124 Training loss: 1.463 Validation loss: 1.467 Validation accuracy: 99.61% times: 871.075658082962
# test accuracy: 98.83
# Epoch cycle: 125 Training loss: 1.463 Validation loss: 1.466 Validation accuracy: 100.00% times: 878.1227300167084
# test accuracy: 100.00
# Save to path: mnist_cnn_model/mnist_cnn.ckpt
# end of training

# %%
# save prediction

#---------------------------------------------------------------#
import pandas as pd

test_df = pd.read_csv('test.csv')
X = test_df.values
print('特征矩阵的形状：', X.shape)
X1 = X[:1000]
X2 = X[1000:2000]
X3 = X[2000:3000]
X4 = X[3000:4000]
X5 = X[4000:5000]
X6 = X[5000:6000]
X7 = X[6000:7000]
X8 = X[7000:8000]
X9 = X[8000:9000]
X10 = X[9000:10000]
X11 = X[10000:11000]
X12 = X[11000:12000]
X13 = X[12000:13000]
X14 = X[13000:14000]
X15 = X[14000:15000]
X16 = X[15000:16000]
X17 = X[16000:17000]
X18 = X[17000:18000]
X19 = X[18000:19000]
X20 = X[19000:20000]
X21 = X[20000:21000]
X22 = X[21000:22000]
X23 = X[22000:23000]
X24 = X[23000:24000]
X25 = X[24000:25000]
X26 = X[25000:26000]
X27 = X[26000:27000]
X28 = X[27000:]

y1 = sess.run(outputs, feed_dict={inputs:X1,keep_prop:1})
y2 = sess.run(outputs, feed_dict={inputs:X2,keep_prop:1})
y3 = sess.run(outputs, feed_dict={inputs:X3,keep_prop:1})
y4 = sess.run(outputs, feed_dict={inputs:X4,keep_prop:1})
y5 = sess.run(outputs, feed_dict={inputs:X5,keep_prop:1})
y6 = sess.run(outputs, feed_dict={inputs:X6,keep_prop:1})
y7 = sess.run(outputs, feed_dict={inputs:X7,keep_prop:1})
y8 = sess.run(outputs, feed_dict={inputs:X8,keep_prop:1})
y9 = sess.run(outputs, feed_dict={inputs:X9,keep_prop:1})
y10 = sess.run(outputs, feed_dict={inputs:X10,keep_prop:1})
y11 = sess.run(outputs, feed_dict={inputs:X11,keep_prop:1})
y12 = sess.run(outputs, feed_dict={inputs:X12,keep_prop:1})
y13 = sess.run(outputs, feed_dict={inputs:X13,keep_prop:1})
y14 = sess.run(outputs, feed_dict={inputs:X14,keep_prop:1})
y15 = sess.run(outputs, feed_dict={inputs:X15,keep_prop:1})
y16 = sess.run(outputs, feed_dict={inputs:X16,keep_prop:1})
y17 = sess.run(outputs, feed_dict={inputs:X17,keep_prop:1})
y18 = sess.run(outputs, feed_dict={inputs:X18,keep_prop:1})
y19 = sess.run(outputs, feed_dict={inputs:X19,keep_prop:1})
y20 = sess.run(outputs, feed_dict={inputs:X20,keep_prop:1})
y21 = sess.run(outputs, feed_dict={inputs:X21,keep_prop:1})
y22 = sess.run(outputs, feed_dict={inputs:X22,keep_prop:1})
y23 = sess.run(outputs, feed_dict={inputs:X23,keep_prop:1})
y24 = sess.run(outputs, feed_dict={inputs:X24,keep_prop:1})
y25 = sess.run(outputs, feed_dict={inputs:X25,keep_prop:1})
y26 = sess.run(outputs, feed_dict={inputs:X26,keep_prop:1})
y27 = sess.run(outputs, feed_dict={inputs:X27,keep_prop:1})
y28 = sess.run(outputs, feed_dict={inputs:X28,keep_prop:1})
import numpy as np
y = np.vstack([y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, y11, y12, y13, y14, y15, y16, y17, y18, y19, y20, y21, y22, y23, y24, y25, y26, y27, y28])
y_argmax = np.argmax(y, 1)
y_argmax.shape
print('predicted shape：', y_argmax.shape)
commit_df = pd.DataFrame({'ImageId': range(1, 1+len(y_argmax)),
                         'Label': y_argmax})
fileName = 'kaggle_commit.csv'
commit_df.to_csv(fileName, index=False)
print('predicted 结果已经保存到文件', fileName)
# Out:
# 特征矩阵的形状： (28000, 784)
# predicted shape： (28000,)
# predicted 结果已经保存到文件 kaggle_commit.csv

# %%
#---------------------------------------------施工中-------------------------------------------------------------#
#CNN model

import numpy as np
import tensorflow as tf

def weight_variable(shape):
    initializer = tf.contrib.layers.xavier_initializer()
    return tf.get_variable('weight',shape,initializer=initializer,dtype=tf.float32)

def bias_variable(shape):
    initialier = tf.constance_initializer()
    return tf.get_variable('bias',shape,initializer=initializer,dtype=tf.float32)

def conv2d(inputs, w):
    return tf.nn.conv2d(inputs,w,strides = [1,1,1,1],padding = 'SAME')

def max_pooling_2x2(inputs,x=2,y=2):
    ksize = [1,x,y,1]
    return tf.nn.max_pool(inputs,ksize,strides = [1,2,2,1],padding = 'SAME')

class MNISTcnn(object):
    def __init__(self,inputs,targets,conf):
        self.inputs = inputs
        self.targets = targets
        self.keep_drop = tf.palceholder(tf.float32)
        
        # 1st layer
        with tf.variable_scope(conv1):
            W_conv1 = weight_variable([5, 5, 1, 32])
            b_conv1 = bias_variable([32])
            h_conv1 = tf.nn.relu(conv2d(self.inputs, W_conv1) + b_conv1)
            h_pool1 = max_pool_2x2(h_conv1)
        # 2nd layer
        with tf.variable__scope(conv2):
            W_conv2 = weight_variable([5, 5, 32, 64])
            b_conv2 = bias_variable([64])
            h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
            h_pool2 = max_pool_2x2(h_conv2)
        #fully connected 1st layer
        with tf.variable_scope("fc1"):
            shape = int(np.prod(h_pool2.get_shape()[1:]))
            W_fc1 = weight_variable([shape, 1024])
            b_fc1 = bias_variable([1024])
            h_pool2_flat = tf.reshape(h_pool2, [-1, shape])
            h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)
        # dropout
        h_fc1_drop = tf.nn.dropout(h_fc1, self.keep_prob)
        #fully connected to outputs
        with tf.variable_scope("fc2"):
            W_fc2 = weight_variable([1024, 10])
            b_fc2 = bias_variable([10])
            outputs = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

        self.loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=self.targets, logits=outputs))
        self.pred = tf.argmax(outputs, 1)

        self.correct_prediction = tf.equal(tf.argmax(outputs,1), tf.argmax(self.targets,1))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
